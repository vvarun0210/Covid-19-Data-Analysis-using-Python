# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\91914\Desktop\RDX\VARUN\Covid-19\country_wise_latest1.csv")

# %%
data
# Out:
#                  Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263  1269.0      25198    9796        106
# 1               Albania       4880   144.0       2745    1991        117
# 2               Algeria      27973  1163.0      18837    7973        616
# 3               Andorra        907    52.0        803      52         10
# 4                Angola        950    41.0        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621    78.0       3752    6791        152
# 183      Western Sahara         10     1.0          8       1          0
# 184               Yemen       1691   483.0        833     375         10
# 185              Zambia       4552   140.0       2815    1597         71
# 186            Zimbabwe       2704    36.0        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.count()
# Out:
# Region                    187
# Confirmed                 187
# Deaths                    166
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.isnull()
# Out:
#      Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0     False      False   False      False   False      False       False
# 1     False      False   False      False   False      False       False
# 2     False      False   False      False   False      False       False
# 3     False      False   False      False   False      False       False
# 4     False      False   False      False   False      False       False
# ..      ...        ...     ...        ...     ...        ...         ...
# 182   False      False   False      False   False      False       False
# 183   False      False   False      False   False      False       False
# 184   False      False   False      False   False      False       False
# 185   False      False   False      False   False      False       False
# 186   False      False   False      False   False      False       False
#
#      New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Region                     0
# Confirmed                  0
# Deaths                    21
# Recovered                  0
# Active                     0
# New cases                  0
# New deaths                 0
# New recovered              0
# Deaths / 100 Cases         0
# Recovered / 100 Cases      0
# Deaths / 100 Recovered     0
# Confirmed last week        0
# 1 week change              0
# 1 week % increase          0
# WHO Region                 0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# TO SEE THE NON NULL VALUES AND NULL VALUES
sns.heatmap(data.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Q1) Show the number of Confirmed, Deaths and Recovered cases in each Region.

# %%
data.head(5)
# Out:
#         Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263  1269.0      25198    9796        106          10
# 1      Albania       4880   144.0       2745    1991        117           6
# 2      Algeria      27973  1163.0      18837    7973        616           8
# 3      Andorra        907    52.0        803      52         10           0
# 4       Angola        950    41.0        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered  Active  New cases  \
# Region
# Afghanistan             36263  1269.0      25198    9796        106
# Albania                  4880   144.0       2745    1991        117
# Algeria                 27973  1163.0      18837    7973        616
# Andorra                   907    52.0        803      52         10
# Angola                    950    41.0        242     667         18
# ...                       ...     ...        ...     ...        ...
# West Bank and Gaza      10621    78.0       3752    6791        152
# Western Sahara             10     1.0          8       1          0
# Yemen                    1691   483.0        833     375         10
# Zambia                   4552   140.0       2815    1597         71
# Zimbabwe                 2704    36.0        542    2126        192
#
#                     New deaths  New recovered  Deaths / 100 Cases  \
# Region
# ...

# %%
data.groupby('Region').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered  Active  New cases  \
# Region
# Afghanistan              36263  1269.0      25198    9796        106
# Albania                   4880   144.0       2745    1991        117
# Algeria                  27973  1163.0      18837    7973        616
# Andorra                    907    52.0        803      52         10
# Angola                     950    41.0        242     667         18
# Antigua and Barbuda         86     3.0         65      18          4
# Argentina               167416  3059.0      72575   91782       4890
# Armenia                  37390   711.0      26665   10014         73
# Australia                15303   167.0       9311    5825        368
# Austria                  20558   713.0      18246    1599         86
# Azerbaijan               30446     0.0      23242    6781        396
# Bahamas                    382     0.0         91     280         40
# ...

# %%
data.groupby('Region')['Confirmed'].sum()
# Out:
# Region
# Afghanistan           36263
# Albania                4880
# Algeria               27973
# Andorra                 907
# Angola                  950
#                       ...
# West Bank and Gaza    10621
# Western Sahara           10
# Yemen                  1691
# Zambia                 4552
# Zimbabwe               2704
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)
# Out:
# Region
# US                       4290259
# Brazil                   2442375
# India                    1480073
# Russia                    816680
# South Africa              452529
#                           ...
# Dominica                      18
# Saint Kitts and Nevis         17
# Greenland                     14
# Holy See                      12
# Western Sahara                10
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = True)
# Out:
# Region
# Western Sahara                10
# Holy See                      12
# Greenland                     14
# Saint Kitts and Nevis         17
# Dominica                      18
#                           ...
# South Africa              452529
# Russia                    816680
# India                    1480073
# Brazil                   2442375
# US                       4290259
# Name: Confirmed, Length: 187, dtype: int64

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)
# Out:
# Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Name: Confirmed, dtype: int64

# %%
data.groupby('Region')['Confirmed','Recovered'].sum()
# Out:
# C:\Users\91914\AppData\Local\Temp\ipykernel_36100\3760683653.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Region')['Confirmed','Recovered'].sum()
#                     Confirmed  Recovered
# Region
# Afghanistan             36263      25198
# Albania                  4880       2745
# Algeria                 27973      18837
# Andorra                   907        803
# Angola                    950        242
# ...                       ...        ...
# West Bank and Gaza      10621       3752
# Western Sahara             10          8
# Yemen                    1691        833
# Zambia                   4552       2815
# Zimbabwe                 2704        542
#
# [187 rows x 2 columns]

# %% [markdown]
# # Q2) Remove all the records where Confirmed cases is less than 10.

# %%
data.head(5)
# Out:
#         Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263  1269.0      25198    9796        106          10
# 1      Albania       4880   144.0       2745    1991        117           6
# 2      Algeria      27973  1163.0      18837    7973        616           8
# 3      Andorra        907    52.0        803      52         10           0
# 4       Angola        950    41.0        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data.Confirmed < 10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# Name: Confirmed, Length: 187, dtype: bool

# %%
data[data.Confirmed < 100]
# Out:
#                                Region  Confirmed  Deaths  Recovered  Active  \
# 5                 Antigua and Barbuda         86     3.0         65      18
# 17                             Belize         48     NaN         26      20
# 19                             Bhutan         99     NaN         86      13
# 49                           Dominica         18     0.0         18       0
# 59                               Fiji         27     0.0         18       9
# 68                          Greenland         14     NaN         13       1
# 69                            Grenada         23     NaN         23       0
# 75                           Holy See         12     0.0         12       0
# 94                               Laos         20     0.0         19       1
# 100                     Liechtenstein         86     1.0         81       4
# 130                  Papua New Guinea         62     0.0         11      51
# ...

# %%
data[~(data.Confirmed < 100)]
# Out:
#                  Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263  1269.0      25198    9796        106
# 1               Albania       4880   144.0       2745    1991        117
# 2               Algeria      27973  1163.0      18837    7973        616
# 3               Andorra        907    52.0        803      52         10
# 4                Angola        950    41.0        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 181             Vietnam        431     0.0        365      66         11
# 182  West Bank and Gaza      10621    78.0       3752    6791        152
# 184               Yemen       1691   483.0        833     375         10
# 185              Zambia       4552   140.0       2815    1597         71
# 186            Zimbabwe       2704    36.0        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data
# Out:
#                  Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263  1269.0      25198    9796        106
# 1               Albania       4880   144.0       2745    1991        117
# 2               Algeria      27973  1163.0      18837    7973        616
# 3               Andorra        907    52.0        803      52         10
# 4                Angola        950    41.0        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621    78.0       3752    6791        152
# 183      Western Sahara         10     1.0          8       1          0
# 184               Yemen       1691   483.0        833     375         10
# 185              Zambia       4552   140.0       2815    1597         71
# 186            Zimbabwe       2704    36.0        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %% [markdown]
# # Q3)  In which Region, Maximum number of cases were recorded ?

# %%
data.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(20)
# Out:
# Region
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Name: Confirmed, dtype: int64

# %% [markdown]
# # Q4) In which Region, Minimum number of deaths were recorded ?

# %%
data.groupby('Region').Deaths.sum().sort_values(ascending = True).head(20)
# Out:
# Region
# Holy See                  0.0
# Botswana                  0.0
# Brazil                    0.0
# Brunei                    0.0
# Bulgaria                  0.0
# Cambodia                  0.0
# Germany                   0.0
# Vietnam                   0.0
# Bosnia and Herzegovina    0.0
# Mongolia                  0.0
# Dominica                  0.0
# Timor-Leste               0.0
# Eritrea                   0.0
# Fiji                      0.0
# Grenada                   0.0
# Greenland                 0.0
# Greece                    0.0
# Laos                      0.0
# Bolivia                   0.0
# Ghana                     0.0
# Name: Deaths, dtype: float64

# %% [markdown]
# # Q5) How many Confirmed, Deaths & recovered cases were reported from India till present?

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263  1269.0      25198    9796        106          10
# 1        Albania       4880   144.0       2745    1991        117           6
# 2        Algeria      27973  1163.0      18837    7973        616           8
# 3        Andorra        907    52.0        803      52         10           0
# 4         Angola        950    41.0        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
data[data.Region == 'India']
# Out:
#    Region  Confirmed   Deaths  Recovered  Active  New cases  New deaths  \
# 79  India    1480073  33408.0     951166  495499      44457         637
#
#     New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 79          33598                2.26                  64.26
#
#     Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 79                    3.51              1155338         324735
#
#     1 week % increase       WHO Region
# 79              28.11  South-East Asia

# %% [markdown]
# # Q6a) Sort the entire data wrt to no. of confirmed cases in ascending order?

# %%
data.sort_values(by = ['Confirmed'] , ascending =True).head(50)
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active  \
# 183                    Western Sahara         10     1.0          8       1
# 75                           Holy See         12     0.0         12       0
# 68                          Greenland         14     NaN         13       1
# 140             Saint Kitts and Nevis         17     0.0         15       2
# 49                           Dominica         18     0.0         18       0
# 94                               Laos         20     0.0         19       1
# 69                            Grenada         23     NaN         23       0
# 168                       Timor-Leste         24     0.0          0      24
# 141                       Saint Lucia         24     0.0         22       2
# 59                               Fiji         27     0.0         18       9
# 17                             Belize         48     NaN         26      20
# ...

# %% [markdown]
# # Q6a) Sort the entire data wrt to no. of recovered cases in descending order?

# %%
data.sort_values(by = ['Recovered'] , ascending =False).head(50)
# Out:
#                    Region  Confirmed    Deaths  Recovered   Active  New cases  \
# 23                 Brazil    2442375       NaN    1846641   508116      23284
# 173                    US    4290259  148011.0    1325804  2816444      56336
# 79                  India    1480073   33408.0     951166   495499      44457
# 138                Russia     816680   13334.0     602249   201097       5607
# 35                  Chile     347923    9187.0     319954    18782       2133
# 111                Mexico     395489   44022.0     303810    47657       4973
# 154          South Africa     452529    7067.0     274925   170537       7096
# 132                  Peru     389717   18418.0     272547    98752      13756
# 81                   Iran     293606   15912.0     255144    22550       2434
# 128              Pakistan     274289    5842.0     241026    27421       1176
# 145          Saudi Arabia     268934    2760.0     222936    43238       1993
# ...
